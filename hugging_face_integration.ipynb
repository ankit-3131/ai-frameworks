# %%
# !pip install -U "langchain[google-genai]"
import os
import getpass

from langchain.chat_models import init_chat_model
from google.colab import userdata

os.environ["GOOGLE_API_KEY"] = userdata.get('GEMINI_API_KEY')

if "GOOGLE_API_KEY" not in os.environ:
    os.environ["GOOGLE_API_KEY"] = getpass.getpass("Enter your Google AI API key: ")
model = init_chat_model("google_genai:gemini-3-flash-preview")

result = model.invoke("what is the capital of france")
print(result.text)
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.5/66.5 kB 2.7 MB/s eta 0:00:00
# ...
# The capital of France is **Paris**.

# %%
# !pip install -qU langchain-nvidia-ai-endpoints
import getpass
import os

from langchain_nvidia_ai_endpoints import ChatNVIDIA
from google.colab import userdata

os.environ["NVIDIA_API_KEY"] = userdata.get('NVIDIA_API_KEY')

llm = ChatNVIDIA(model="nvidia/nemotron-3-nano-30b-a3b")
result = llm.invoke("write backtest code in python for average reversal strategy")
print(result.content)
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.5/51.5 kB 1.9 MB/s eta 0:00:00
#
# Below is a **complete, self‑contained Python notebook‑style script** that implements a very simple **Mean‑Reversion / “Average Reversal”** back‑test.
#
# *The idea*:
# - Compute a rolling “average” (e.g., a Simple Moving Average, SMA) of the price series.
# - When the price deviates enough from that average (e.g., more than *n* standard deviations) we **enter a long position** (expecting the price to “re‑reverse” back toward the mean).
# - We exit when the price reaches the average again (or after a fixed stop‑loss / take‑profit).
#
# The script uses only the standard data‑science stack (`pandas`, `numpy`, `matplotlib`) and a tiny helper class to keep the back‑test logic tidy. Feel free to swap in other data sources, metrics, or execution logic.
#
# ---
#
# ## 1️⃣  Install / import required packages
# ```python
# # If you run this in a fresh environment, uncomment the first cell and run:
# ...

# %%
# !pip install -qU huggingface_hub
from langchain_huggingface import ChatHuggingFace
from langchain_huggingface import HuggingFaceEndpoint
import os
from google.colab import userdata


os.environ["HUGGINGFACEHUB_API_TOKEN"] = userdata.get('HUGGINGFACEHUB_API_TOKEN')

# Changed to a more robustly supported model for Hugging Face Inference API
repo_id = "---give some latest working repo id here---"

model = HuggingFaceEndpoint(
    repo_id=repo_id,
    huggingfacehub_api_token=userdata.get('HUGGINGFACEHUB_API_TOKEN'), # Uncommented this line
    provider="auto",
)
class Poem(BaseModel):
  verse: str = Field(description="poem verse")
  tone: Literal["happy","sad","melancholy"] = Field(description = "if any other specify that")

# The structured output part was previously commented out, this is a separate concern.
# If you wish to use structured output, remember that HuggingFaceEndpoint does not natively support
# .with_structured_output(). You would need to prompt for JSON and parse it manually.
# model = model_without_strutured.with_structured_output(Poem, include_raw = True)

result = model.invoke("write a poem about watching moon at the shore")
print(result)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_714/888245815.py in <cell line: 0>()
#       1 get_ipython().system('pip install -qU huggingface_hub')
# ----> 2 from langchain_huggingface import ChatHuggingFace
#       3 from langchain_huggingface import HuggingFaceEndpoint
#       4 import os
#       5 from google.colab import userdata
#
# ModuleNotFoundError: No module named 'langchain_huggingface'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
